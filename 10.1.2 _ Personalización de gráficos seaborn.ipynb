# %%
import pandas as pd

df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
import seaborn as sns
for style in ["dark", "whitegrid", "darkgrid", "ticks"]:
    sns.set_style(style)
    sns.displot(df["reading score"])
# Out:
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Remoción de ejes
sns.set_style("ticks")
sns.displot(df["reading score"], kde=True)
sns.despine(left=True, bottom=True)
# Out:
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Combinación de parámetros con MatPlotLib
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
sns.distplot(df["writing score"], ax=ax)
ax.set(xlabel="Puntaje de escritura", ylabel="Frecuencia relativa")
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_77445/1427753064.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax=ax)
# [Text(0.5, 0, 'Puntaje de escritura'), Text(0, 0.5, 'Frecuencia relativa')]

# %%
# Truncamiento de escala de visualización
fig, ax = plt.subplots()
sns.distplot(df["writing score"], ax=ax)
ax.set(xlabel="Puntaje de escritura", ylabel="Frecuencia relativa", xlim=(0,90),
      title="Histograma de frecuencias relativas para puntajes de escritura")
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_77445/1328785946.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax=ax)
# [Text(0.5, 0, 'Puntaje de escritura'),
#  Text(0, 0.5, 'Frecuencia relativa'),
#  (0.0, 90.0),
#  Text(0.5, 1.0, 'Histograma de frecuencias relativas para puntajes de escritura')]

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True)
sns.distplot(df["writing score"], ax=ax0) # Histograma para todas las observaciones
sns.distplot(df.query('gender == "male"')["writing score"], ax=ax1) # Histograma para los hombres
ax0.set(xlabel="Puntaje general de escritura")
ax1.set(xlabel="Puntaje de escritura para hombres")
ax1.axvline(x=75, label="Objetivo", linestyle="--")
ax1.legend()
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_77445/899158848.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax=ax0) # Histograma para todas las observaciones
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_77445/899158848.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.query('gender == "male"')["writing score"], ax=ax1) # Histograma para los hombres

# %%
# Asignación de colores al histograma
paleta = ["deep", "muted", "pastel", "bright", "dark", "colorblind"]

for p in paleta:
    sns.set_palette(p)
    sns.displot(df["reading score"], kde=True)
# Out:
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
