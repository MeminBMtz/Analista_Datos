# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# Creación de un stripplot (Gráfico de franjas / bandas)
import seaborn as sns
sns.stripplot(data=df, y="writing score", x="math score", jitter=True)
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
sns.stripplot(data=df, y="writing score", x="math score", jitter=True)
ax.axes.xaxis.set_ticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
sns.stripplot(data=df, y="writing score", x="race/ethnicity", jitter=True, hue="race/ethnicity",legend=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Creación de un swarmplot (diagrama de enjambre)
# Busca colocar las observaciones de manera que no se empalmen
sns.swarmplot(data=df, y="writing score", x="race/ethnicity", hue="race/ethnicity",legend=False)
# Out:
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 17.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Creación de un boxplot (diagrama de caja)
sns.boxplot(data=df, y="writing score", x="race/ethnicity")
plt.legend([], [], frameon=False)

# %%
# Creación de un gráfico de violín
# Mezcla de un boxplot con funciónd de densidad Kernel
sns.violinplot(data=df, y="writing score", x="race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creación de un lvplot (Letter-Value plot)
# Mezcla del boxplot y el violinplot, conveniente para bases de datos grandes
sns.catplot(data=df, y="writing score", x="race/ethnicity", kind="boxen")
# Out:
# /Users/memobarbosa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Creación de un barplot
sns.barplot(data=df, x="race/ethnicity", y="writing score")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creación de un barplot (gráfico de barras)
sns.barplot(data=df, x="race/ethnicity", y="writing score", hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creación de un pointplot (gráfico de puntos)
sns.pointplot(data=df, x="race/ethnicity", y="writing score", hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# Creación de un countplot (gráfico de puntos)
sns.countplot(data=df, y="race/ethnicity", hue="lunch")
# Out:
# <Axes: xlabel='count', ylabel='race/ethnicity'>

# %%
# Gráficos de regresión con regplot
sns.regplot(data=df, y="writing score", x="reading score", marker="+")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# Gráfico de residuales
sns.residplot(data=df, y="writing score", x="reading score")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# Gráficos de regresión con regplot y media por valor de x
# Muy útil para enfatizar tendencias
import numpy as np
sns.regplot(data=df, y="writing score", x="reading score", x_estimator=np.mean)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# Creación de un mapa de calor para una matriz de correlación
sns.heatmap(df[["math score", "reading score", "writing score"]].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df[["math score", "reading score", "writing score"]].corr(), annot=True)
# Out:
# <Axes: >

# %%
# Creación de una tabla cruzada
pd.crosstab(df["gender"], df["race/ethnicity"], values=df["math score"], aggfunc="mean")
# Out:
# race/ethnicity    group A    group B    group C    group D    group E
# gender
# female          58.527778  61.403846  62.033333  65.248062  70.811594
# male            63.735849  65.930233  67.611511  69.413534  76.746479

# %%
# Creación de un mapa de calor para una tabla cruzada
sns.heatmap(pd.crosstab(df["gender"], df["race/ethnicity"], values=df["math score"], aggfunc="mean"), annot=True)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='gender'>
