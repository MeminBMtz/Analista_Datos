# %% [markdown]
# # https://forum.easydatatransform.com/t/olympic-medals-table-csv/289

# %%
import pandas as pd

df = pd.read_csv("olympic-medals.csv")
df
# Out:
#                           TEAM  Gold  Silver  Bronze
# 0     United States of America    39      41      33
# 1   People's Republic of China    38      32      18
# 2                        Japan    27      14      17
# 3                Great Britain    22      21      22
# 4                          ROC    20      28      23
# ..                         ...   ...     ...     ...
# 88                       Ghana     0       0       1
# 89                     Grenada     0       0       1
# 90                      Kuwait     0       0       1
# 91         Republic of Moldova     0       0       1
# 92        Syrian Arab Republic     0       0       1
#
# [93 rows x 4 columns]

# %%
df = pd.read_csv("olympic-medals.csv", index_col=0)
df
# Out:
#                             Gold  Silver  Bronze
# TEAM
# United States of America      39      41      33
# People's Republic of China    38      32      18
# Japan                         27      14      17
# Great Britain                 22      21      22
# ROC                           20      28      23
# ...                          ...     ...     ...
# Ghana                          0       0       1
# Grenada                        0       0       1
# Kuwait                         0       0       1
# Republic of Moldova            0       0       1
# Syrian Arab Republic           0       0       1
#
# [93 rows x 3 columns]

# %%
medallas = df.head(10)
medallas
# Out:
#                             Gold  Silver  Bronze
# TEAM
# United States of America      39      41      33
# People's Republic of China    38      32      18
# Japan                         27      14      17
# Great Britain                 22      21      22
# ROC                           20      28      23
# Australia                     17       7      22
# Netherlands                   10      12      14
# France                        10      12      11
# Germany                       10      11      16
# Italy                         10      10      20

# %%
# Visualización de medallas de oro y plata
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas["Gold"])
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas["Gold"])
ax.set_xticklabels(medallas.index, rotation=90)
ax.set_ylabel("Número de medallas")
plt.show()
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_37375/3428841493.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medallas.index, rotation=90)

# %%
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas["Gold"])
ax.bar(medallas.index, medallas["Silver"], bottom=medallas["Gold"])
ax.set_xticklabels(medallas.index, rotation=90)
ax.set_ylabel("Número de medallas")
plt.show()
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_37375/2311839077.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medallas.index, rotation=90)

# %%
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas["Gold"])
ax.bar(medallas.index, medallas["Silver"], bottom=medallas["Gold"])
ax.bar(medallas.index, medallas["Bronze"], bottom=medallas["Gold"] + medallas["Silver"])
ax.set_xticklabels(medallas.index, rotation=90)
ax.set_ylabel("Número de medallas")
plt.show()
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_37375/3440763840.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medallas.index, rotation=90)

# %%
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas["Gold"])
ax.bar(medallas.index, medallas["Silver"], bottom=medallas["Gold"])
ax.bar(medallas.index, medallas["Bronze"], bottom=medallas["Gold"] + medallas["Silver"])
ax.set_xticklabels(medallas.index, rotation=90)
ax.set_ylabel("Número de medallas")
ax.legend(["Gold", "Silver", "Bronze"])
plt.show()
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_37375/2450823933.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medallas.index, rotation=90)

# %%
# Creación de un histograma
fig, ax = plt.subplots()
ax.hist(df["Gold"])
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["Gold"])
ax.hist(df["Silver"])
ax.set_xlabel("# de medallas")
ax.set_ylabel("# de observaciones")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["Gold"], label="Oro")
ax.hist(df["Silver"], label="Plata")
ax.set_xlabel("# de medallas")
ax.set_ylabel("# de observaciones")
ax.legend()
plt.show()

# %%
# Creación de histogramas con especificación de intervalos
fig, ax = plt.subplots()
ax.hist(df["Gold"], label="Oro", bins=[0,5,10,15,20,25,30,35,40])
ax.hist(df["Silver"], label="Plata", bins=[0,5,10,15,20,25,30,35,40])
ax.set_xlabel("# de medallas")
ax.set_ylabel("# de observaciones")
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["Gold"], label="Oro", bins=[0,5,10,15,20,25,30,35,40], histtype="step")
ax.hist(df["Silver"], label="Plata", bins=[0,5,10,15,20,25,30,35,40], histtype="step")
ax.set_xlabel("# de medallas")
ax.set_ylabel("# de observaciones")
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot([df["Gold"], df["Silver"]])
ax.set_xticklabels(["Oro", "Plata"])
ax.set_ylabel("# de medallas")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(df["Gold"], df["Silver"])
ax.set_xlabel("# de medallas de oro")
ax.set_ylabel("# de medallas de plata")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(df["Gold"], df["Silver"], color="red", label="plata")
ax.scatter(df["Gold"], df["Bronze"], color="blue", label="bronce")
ax.set_xlabel("# de medallas de oro")
ax.set_ylabel("# de medallas de plata")
ax.legend()
plt.show()

# %%
df = pd.read_csv("olympic-medals.csv")
df
# Out:
#                           TEAM  Gold  Silver  Bronze
# 0     United States of America    39      41      33
# 1   People's Republic of China    38      32      18
# 2                        Japan    27      14      17
# 3                Great Britain    22      21      22
# 4                          ROC    20      28      23
# ..                         ...   ...     ...     ...
# 88                       Ghana     0       0       1
# 89                     Grenada     0       0       1
# 90                      Kuwait     0       0       1
# 91         Republic of Moldova     0       0       1
# 92        Syrian Arab Republic     0       0       1
#
# [93 rows x 4 columns]

# %%
# Creación de gráficos de dispersión con degradado en color
fig, ax = plt.subplots()
ax.scatter(df["Gold"], df["Silver"], c=df.index)
ax.set_xlabel("# de medallas de oro")
ax.set_ylabel("# de medallas de plata")
plt.show()
