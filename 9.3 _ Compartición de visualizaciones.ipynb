# %%
import pandas as pd

df = pd.read_csv("co2-mm-mlo.csv")
df.reset_index(inplace=True); df.drop(columns=["Number of Days", "Trend"], inplace=True)
df.rename(columns = {'index': 'Date', 'Date': 'Decimal Date', 'Decimal Date': 'Interpolated',
                     'Average': 'Trend','Interpolated': 'Number of Days'}, inplace=True);
df["Average"] = (df["Interpolated"] + df["Trend"]) / 2; df
# Out:
#         Date  Decimal Date  Interpolated   Trend  Number of Days  Average
# 0    1958-03     1958.2027        315.70  314.43              -1  315.065
# 1    1958-04     1958.2877        317.45  315.16              -1  316.305
# 2    1958-05     1958.3699        317.51  314.71              -1  316.110
# 3    1958-06     1958.4548        317.24  315.14              -1  316.190
# 4    1958-07     1958.5370        315.86  315.18              -1  315.520
# ..       ...           ...           ...     ...             ...      ...
# 786  2023-09     2023.7083        418.51  421.96              18  420.235
# 787  2023-10     2023.7917        418.82  422.12              27  420.470
# 788  2023-11     2023.8750        420.46  422.43              21  421.445
# 789  2023-12     2023.9583        421.86  422.56              20  422.210
# 790  2024-01     2024.0417        422.80  422.53              27  422.665
#
# [791 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
fechas = df[(df["Date"] >= "2015-01") & (df["Date"] <= "2018-09")]

fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()

# %%
plt.style.use("ggplot")

fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()

# %%
# Re-inicialización del estilo de gráfico por "default"
plt.style.use("default")
fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()

# %%
# Estilo "bmh"
plt.style.use("bmh")
fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()

# %%
# Estilo "seaborn"
plt.style.use("seaborn-colorblind")
fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()
# Out:
# /var/folders/kc/sj9l8byj6ssgcctgfvyh7gx80000gn/T/ipykernel_43259/2263666731.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
# Estilo "tableau"
plt.style.use("tableau-colorblind10")
fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()

# %%
# Estilo "grayscale"
plt.style.use("grayscale")
fig, ax = plt.subplots()
ax.plot(fechas["Date"], fechas["Interpolated"])
ax.axes.xaxis.set_ticks([])
plt.xlabel("Datos mensuales: 01-01-2015 - 01-09-2018")
plt.ylabel("Emisiones de CO2 promedio")
plt.show()

# %%
fig.savefig("medallas.png")

# %%
# Para determinar en dónde se guardó el archivo
import pathlib
pathlib.Path().resolve()
# Out:
# PosixPath('/Users/memobarbosa')

# %%
ls
# Out:
# 1. Variables, expresiones y enunciados.ipynb
# 2.1 Manejo de cadenas.ipynb
# 2.2 Manejo de listas.ipynb
# 2.5 Actividad práctica.ipynb
# 3. Manejo de diccionarios.ipynb
# 3.1 Introducción a las tablas de verdad (and, or, not).ipynb
# 3.2 IF, ELSE y ELIF.ipynb
# 4. Manejo de tuplas.ipynb
# 4.1 | La instrucción "while".ipynb
# 4.2 | La instrucción "for".ipynb
# 5.1 | Propósito y tipos de funciones en Python.ipynb
# 5.2 | Recursividad en Python.ipynb
# 6.1 | Definición de clases, objetos y constructores en Python.ipynb
# 6.2 | Aplicaciones avanzadas de constructores en Python.ipynb
# 7.1 | Transformación de Dataframes.ipynb
# 7.2.1 | Agregación de Dataframes y extracción e indexación en Dataframes.ipynb
# 7.2.2 Extracción e indexación en Dataframes.ipynb
# 7.3 | Creación y visualización de Dataframes.ipynb
# 8.1 | Arreglos de NumPy.ipynb
# 8.2 | Métodos y operaciones de NumPy.ipynb
# 8.3 | Indexación y asignaciones con NumPy.ipynb
# 9.1 | Introducción a la visualización con MatPlotLib.ipynb
# 9.2.1 | Graficación de series de tiempo.ipynb
# 9.2.2 | Visualizaciones cuantitativas y estadísticas.ipynb
# 9.3 | Compartición de visualizaciones.ipynb
# Applications/
# Desktop/
# Documents/
# Downloads/
# ElRamoAzul.txt
# Iris.csv
# Iris2.csv
# Library/
# M03 Actividad.ipynb
# M04 Actividad.ipynb
# M05 Actividad.ipynb
# M06 Actividad.ipynb
# M07 Actividad.ipynb
# M08 Actividad.ipynb
# Movies/
# Music/
# Pictures/
# Primera lección - Instalación.ipynb
# Programa 1.ipynb
# Public/
# Trabalenguas.txt
# Untitled Folder/
# Untitled.ipynb
# anaconda3/
# co2-mm-mlo.csv
# get-pip.py
# medallas.png
# olympic-medals.csv
# wekafiles/

# %%
# Resolución de 100 dpi's
fig.savefig("medallas.png", dpi=100)

# %%
fig.savefig("medallas.png", dpi=300)

# %%
# Formato de jpg
fig.savefig("medallas.jpg")
