# %% [markdown]
# # Lectura del archivo e impresión de primeras y últimas filas y una muestra

# %%
import pandas as pd
import numpy as np

# Lectura del archivo
df = pd.read_csv('fifa_eda.csv')

# Primeras 20 filas del archivo
df.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
# Últimas 5 filas del archivo
df.tail(5)
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
# Sample de 10 filas del archivo
df.sample(10)
# Out:
#            ID            Name  Age   Nationality  Overall  Potential  \
# 1920   216749     Carlos Mané   24      Portugal       75         81
# 9589   233397     A. Diawusie   20       Germany       66         77
# 11483  228983     M. Caufriez   21       Belgium       64         72
# 11221  239412     G. Loiacono   26         Italy       64         64
# 3369   202547     J. Bahebeck   25        France       72         75
# 3938   235512     Gelson Dala   21        Angola       72         82
# 1463   225201  Alex Berenguer   22         Spain       76         81
# 10710  224449      H. Ekstein   27  South Africa       65         66
# 12040  190201      M. Minesso   28         Italy       64         64
# 12147  181010      L. Broxham   30     Australia       63         63
#
#                     Club    Value  Wage Preferred Foot  \
# 1920         Sporting CP   9000.0  11.0          Right
# 9589    FC Ingolstadt 04   1100.0   6.0          Right
# ...

# %% [markdown]
# # Datos del dataset (estadísticos y tipos)

# %%
# Datos estadísticos del dataframe
df.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
# Tipos de datos del dataset
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %% [markdown]
# # Transformación e impresión de columna numérica

# %% [markdown]
# La columna "Contract Valid Until" cuenta con números. En lugar de contar con la fecha, se transformará al año en que el contrato de un jugador es válido. Practicando con el dataset vi que había valores nulos, a los cuales asignaré el año más frecuente.

# %%
df['Contract Valid Until'].value_counts()
# Out:
# Contract Valid Until
# 2019-01-01    4870
# 2021-01-01    4360
# 2020-01-01    4027
# 2022-01-01    1477
# 2023-01-01    1053
# 2019-06-30     931
# 2018-01-01     886
# 2018-12-31     144
# 2019-05-31      60
# 2024-01-01      23
# 2020-06-30      14
# 2019-01-31      13
# 2025-01-01       7
# 2019-01-05       6
# 2019-01-02       6
# 2019-10-14       5
# 2019-01-12       5
# 2019-01-06       4
# 2019-12-31       3
# 2019-01-07       3
# 2019-01-25       3
# 2026-01-01       2
# 2019-12-01       2
# 2020-05-31       2
# 2018-11-30       2
# 2019-01-15       1
# 2020-02-27       1
# 2019-01-30       1
# 2019-01-11       1
# 2019-05-04       1
# 2019-01-18       1
# 2019-01-03       1
# 2019-01-04       1
# 2019-06-01       1
# 2019-01-20       1
# Name: count, dtype: int64

# %%
years = []
for year in df["Contract Valid Until"]:
    if type(year) == str: years.append(int(year[:4])) # Es un valor entero
    else: years.append('nan') # Es float (nan)

from statistics import mode
most_common_year = mode(years) # Año más frecuente

for i in range(len(years)):
    if years[i] == 'nan': # Iteramos la lista por índice y si el valor es nan se asigna el año más frecuente
        years[i] = most_common_year

# Cambiamos los valores del dataset
df['Contract Valid Until'] = np.array(years)
df['Contract Valid Until'].astype('int64') # Los volvemos numéricos de tipo int64

df.sample(5) # Muestra de 5 filas
# Out:
#            ID          Name  Age Nationality  Overall  Potential  \
# 8973   229677    F. Bambock   23      France       66         70
# 16550  242613    D. Cayupil   20       Chile       57         71
# 6672   227600  J. Andersson   21      Sweden       68         76
# 10709  203457     M. Fetsch   29     Germany       65         65
# 5690   223501     A. Spörle   22   Argentina       69         78
#
#                          Club   Value  Wage Preferred Foot  \
# 8973               Córdoba CF   700.0   2.0          Right
# 16550    Club Deportes Temuco   200.0   1.0           Left
# 6672           FC Midtjylland  1100.0   6.0          Right
# 10709           Hallescher FC   550.0   2.0          Right
# 5690   Club Atlético Banfield  1400.0   6.0           Left
#
#        International Reputation  Skill Moves Position  Joined  \
# 8973                        1.0          2.0      CDM    2018
# 16550                       1.0          2.0       LB    2018
# ...

# %% [markdown]
# ## Datos (estadísticos y tipos) con la nueva columna

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until          int64
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %% [markdown]
# # Nueva columna

# %%
# Se agrega la columna 'Years Playing' teniendo en cuenta el año actual y el año en que se unieron
current_year = 2024
df["Years Playing"] = current_year - df["Joined"]

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %% [markdown]
# # Filtro para jugadores de México

# %%
# Jugadores de México
mexico_players = df.loc[df['Nationality'] == 'Mexico']

# %%
mexico_players
# Out:
#            ID          Name  Age Nationality  Overall  Potential  \
# 306    171897   A. Guardado   31      Mexico       82         82
# 329    221992     H. Lozano   22      Mexico       81         86
# 371    193165     J. Corona   25      Mexico       81         83
# 397    169416       C. Vela   29      Mexico       81         81
# 406    156519    H. Herrera   28      Mexico       81         81
# ...       ...           ...  ...         ...      ...        ...
# 17373  244828  R. Gutiérrez   22      Mexico       54         64
# 17614  239739      A. Ocejo   20      Mexico       53         62
# 18037  246089      C. Landa   19      Mexico       50         60
# 18068  240286     J. García   20      Mexico       50         62
# 18113  237045    R. Pasquel   22      Mexico       50         60
#
#                               Club    Value  Wage Preferred Foot  \
# 306                     Real Betis  19000.0  35.0           Left
# ...

# %% [markdown]
# # Ordenados y mostrados por columna 'Release Clause'

# %%
sorted_release_clause = df.sort_values(by='Release Clause')
sorted_release_clause
# Out:
#            ID              Name  Age Nationality  Overall  Potential  \
# 16204  176860        C. Månsson   37      Sweden       58         58
# 17209  237751        Y. Nishibe   37       Japan       55         55
# 16249  176631       B. Lekström   37      Sweden       58         58
# 16565  232893       K. Kitamoto   36       Japan       57         57
# 16628  102881  K. Stamatopoulos   38      Canada       57         57
# ...       ...               ...  ...         ...      ...        ...
# 25     231747         K. Mbappé   19      France       88         95
# 5      183277         E. Hazard   27     Belgium       91         91
# 4      192985      K. De Bruyne   27     Belgium       91         92
# 0      158023          L. Messi   31   Argentina       94         94
# 2      190871         Neymar Jr   26      Brazil       92         93
#
#                       Club     Value   Wage Preferred Foot  \
# 16204      Kristiansund BK      10.0    1.0          Right
# ...

# %% [markdown]
# # Nuevo dataset (por año, size, renombre y gráfico)

# %%
new_dataset = df.groupby("Joined").size().rename('Num. Jugadores').reset_index()

# %%
new_dataset
# Out:
#     Joined  Num. Jugadores
# 0     1991               1
# 1     1998               3
# 2     1999               1
# 3     2000               2
# 4     2001               2
# 5     2002              10
# 6     2003              13
# 7     2004              12
# 8     2005              17
# 9     2006              18
# 10    2007              38
# 11    2008              53
# 12    2009              78
# 13    2010             131
# 14    2011             201
# 15    2012             340
# 16    2013             458
# 17    2014             818
# 18    2015            1336
# 19    2016            3799
# 20    2017            4307
# 21    2018            6569

# %%
new_dataset.plot.bar(x='Joined', y='Num. Jugadores')
# Out:
# <Axes: xlabel='Joined'>
